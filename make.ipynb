# %% [markdown]
# # A simple predictive analysis, regression,  about gold's opening value .

# %%
import time
# %run resume.ipynb
yahoo_file()
time.sleep(3)
Pyauto_move()
analyser()
# %run Untitled.ipynb
run()
time.sleep(15)
yahoo_mail()
del_make()
faceBook()
link()
netflix()
# Out:
#           Date         Open         High          Low        Close  \
# 249 2021-04-29  1781.000000  1789.000000  1758.599976  1768.099976
# 250 2021-04-30  1771.800049  1771.800049  1763.900024  1767.300049
# 251 2021-05-03  1788.500000  1793.000000  1788.500000  1791.400024
#
#        Adj Close  Volume
# 249  1768.099976   196.0
# 250  1767.300049    18.0
# 251  1791.400024    18.0
# The R2's value is 0.995
# The variance's value is 0.995
# The MSE's value is 41.300
# The Max error's value is 21.347
#         y_test    y_predict      error
# 0  2040.099976  2050.221783  10.121807
# 1  1788.500000  1788.704632   0.204632
# 2  1726.900024  1732.459067   5.559043

# %% [markdown]
# ### The conclusion is that method is able for predict the opening's value well, showing that the variance value is less then one.
